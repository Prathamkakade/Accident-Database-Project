# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# read the dataset
df = pd.read_csv('US_Accidents_Dec21_updated.csv')

# %%
df1=df
df.describe
df.dropna()
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 42            A-43         4  2016-02-09 18:20:58  2016-02-10 00:20:58
# 43            A-44         4  2016-02-09 18:20:58  2016-02-10 00:20:58
# 47            A-48         4  2016-02-10 06:18:49  2016-02-10 12:18:49
# 50            A-51         2  2016-02-10 08:35:27  2016-02-10 14:35:27
# 66            A-67         2  2016-02-10 12:54:39  2016-02-10 18:54:39
# ...            ...       ...                  ...                  ...
# 2845298  A-2845299         3  2019-08-23 16:19:21  2019-08-23 16:48:04
# 2845302  A-2845303         4  2019-08-23 17:25:12  2019-08-23 17:54:00
# 2845303  A-2845304         4  2019-08-23 17:25:12  2019-08-23 17:54:00
# 2845304  A-2845305         3  2019-08-23 01:16:01  2019-08-23 01:44:53
# 2845307  A-2845308         3  2019-08-23 10:32:30  2019-08-23 11:01:40
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# ...

# %%
df1
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 0              A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08
# 1              A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20
# 2              A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39
# 3              A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45
# 4              A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43
# ...            ...       ...                  ...                  ...
# 2845337  A-2845338         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# 2845338  A-2845339         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# 2845339  A-2845340         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 2845340  A-2845341         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 2845341  A-2845342         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
list1=[]
for i in range(0,len(df)):
    list1.append(random.randint(0,1))
df["Amenity"]=list1
df["Amenity"]=df["Amenity"].map({1: True, 0: False})


list2=[]
for i in range(0,len(df)):
    list2.append(random.randint(0,1))
df["Bump"]=list2
df["Bump"]=df["Bump"].map({1: True, 0: False})


list3=[]
for i in range(0,len(df)):
    list3.append(random.randint(0,1))
df["Crossing"]=list3
df["Crossing"]=df["Crossing"].map({1: True, 0: False})


list4=[]
for i in range(0,len(df)):
    list4.append(random.randint(0,1))
df["Give_Way"]=list4
df["Give_Way"]=df["Give_Way"].map({1: True, 0: False})


list5=[]
for i in range(0,len(df)):
    list5.append(random.randint(0,1))
df["Junction"]=list5
df["Junction"]=df["Junction"].map({1: True, 0: False})


list6=[]
for i in range(0,len(df)):
    list6.append(random.randint(0,1))
df["No_Exit"]=list6
df["No_Exit"]=df["No_Exit"].map({1: True, 0: False})


list7=[]
for i in range(0,len(df)):
    list7.append(random.randint(0,1))
df["Railway"]=list7
df["Railway"]=df["Railway"].map({1: True, 0: False})


list8=[]
for i in range(0,len(df)):
    list8.append(random.randint(0,1))
df["Roundabout"]=list8
df["Roundabout"]=df["Roundabout"].map({1: True, 0: False})


list9=[]
for i in range(0,len(df)):
    list9.append(random.randint(0,1))
df["Station"]=list9
df["Station"]=df["Station"].map({1: True, 0: False})


list10=[]
for i in range(0,len(df)):
    list10.append(random.randint(0,1))
df["Stop"]=list10
df["Stop"]=df["Stop"].map({1: True, 0: False})


list11=[]
for i in range(0,len(df)):
    list11.append(random.randint(0,1))
df["Traffic_Calming"]=list11
df["Traffic_Calming"]=df["Traffic_Calming"].map({1: True, 0: False})


list12=[]
for i in range(0,len(df)):
    list12.append(random.randint(0,1))
df["Traffic_Signal"]=list12
df["Traffic_Signal"]=df["Traffic_Signal"].map({1: True, 0: False})


list13=[]
for i in range(0,len(df)):
    list13.append(random.randint(0,1))
df["Turning_Loop"]=list13
df["Turning_Loop"]=df["Turning_Loop"].map({1: True, 0: False})

# %%
df
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 0              A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08
# 1              A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20
# 2              A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39
# 3              A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45
# 4              A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43
# ...            ...       ...                  ...                  ...
# 2845337  A-2845338         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# 2845338  A-2845339         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# 2845339  A-2845340         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 2845340  A-2845341         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 2845341  A-2845342         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# ...

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# ID                       0
# Severity                 0
# Start_Time               0
# End_Time                 0
# Start_Lat                0
# Start_Lng                0
# End_Lat                  0
# End_Lng                  0
# Distance(mi)             0
# Description              0
# Number                   0
# Street                   0
# Side                     0
# City                     0
# County                   0
# State                    0
# Zipcode                  0
# Country                  0
# Timezone                 0
# Airport_Code             0
# Weather_Timestamp        0
# Temperature(F)           0
# Wind_Chill(F)            0
# Humidity(%)              0
# Pressure(in)             0
# Visibility(mi)           0
# Wind_Direction           0
# Wind_Speed(mph)          0
# Precipitation(in)        0
# Weather_Condition        0
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# ...

# %%
df
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 42            A-43         4  2016-02-09 18:20:58  2016-02-10 00:20:58
# 43            A-44         4  2016-02-09 18:20:58  2016-02-10 00:20:58
# 47            A-48         4  2016-02-10 06:18:49  2016-02-10 12:18:49
# 50            A-51         2  2016-02-10 08:35:27  2016-02-10 14:35:27
# 66            A-67         2  2016-02-10 12:54:39  2016-02-10 18:54:39
# ...            ...       ...                  ...                  ...
# 2845298  A-2845299         3  2019-08-23 16:19:21  2019-08-23 16:48:04
# 2845302  A-2845303         4  2019-08-23 17:25:12  2019-08-23 17:54:00
# 2845303  A-2845304         4  2019-08-23 17:25:12  2019-08-23 17:54:00
# 2845304  A-2845305         3  2019-08-23 01:16:01  2019-08-23 01:44:53
# 2845307  A-2845308         3  2019-08-23 10:32:30  2019-08-23 11:01:40
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
WeatherIndex=[]
FeatureIndex=[]
LocationIndex=[]
AccidentIndex =[]
for i in range(1,len(df)+1):
    WeatherIndex.append("W-"+str(i))
    FeatureIndex.append("F-"+str(i))
    LocationIndex.append("L-"+str(i))
    AccidentIndex.append("A-"+str(i))
df["WeatherID"]=WeatherIndex
df["FeatureID"]=FeatureIndex
df["LocationID"]=LocationIndex
df["AccidentID"]=AccidentIndex

# %%
df
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 42            A-43         4  2016-02-09 18:20:58  2016-02-10 00:20:58
# 43            A-44         4  2016-02-09 18:20:58  2016-02-10 00:20:58
# 47            A-48         4  2016-02-10 06:18:49  2016-02-10 12:18:49
# 50            A-51         2  2016-02-10 08:35:27  2016-02-10 14:35:27
# 66            A-67         2  2016-02-10 12:54:39  2016-02-10 18:54:39
# ...            ...       ...                  ...                  ...
# 2845298  A-2845299         3  2019-08-23 16:19:21  2019-08-23 16:48:04
# 2845302  A-2845303         4  2019-08-23 17:25:12  2019-08-23 17:54:00
# 2845303  A-2845304         4  2019-08-23 17:25:12  2019-08-23 17:54:00
# 2845304  A-2845305         3  2019-08-23 01:16:01  2019-08-23 01:44:53
# 2845307  A-2845308         3  2019-08-23 10:32:30  2019-08-23 11:01:40
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# ...

# %%
pip install psycopg2

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database="Accident",
    user="postgres",
    password="root",
    port = 5432
)

# %%
cur = conn.cursor()

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight', 'WeatherID', 'FeatureID', 'LocationID',
#        'AccidentID'],
#       dtype='object')

# %%
df_location = df[['LocationID', 'AccidentID','Number', 'Street','Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone','Airport_Code']]
df_feature = df[['FeatureID', 'AccidentID', 'Amenity','Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway','Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal','Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight','Astronomical_Twilight']]
df_accident = df[['AccidentID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng','End_Lat', 'End_Lng', 'Distance(mi)', 'Description']]
df_weather = df[['WeatherID', 'AccidentID', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)','Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction','Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition']]

# %%
df_accident = df_accident.rename(columns={'Distance(mi)': 'Distance'})

# %%
pip install mysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import MySQLdb
engine = create_engine("postgresql://postgres:root@localhost:5432/Accident")
con = engine.connect()
df_accident.to_sql(name = 'accidents', con = con, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1788, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787     if not evt_handled:
# -> 1788         self.dialect.do_executemany(
#    1789             cursor, statement, parameters, context
#    1790         )
#    1791 elif not parameters and context.no_parameters:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py:951, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     950     xtras = self._psycopg2_extras()
# --> 951     context._psycopg2_fetched_rows = xtras.execute_values(
#     952         cursor,
#     953         statement,
#     954         parameters,
#     955         template=executemany_values,
# ...

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database="Accident",
    user="postgres",
    password="root",
    port = 5432
)
cur = conn.cursor()

# %%
cur.execute('''CREATE TABLE Accident (
  AccidentID varchar(50) PRIMARY KEY,
  Severity int,
  Start_Time timestamp,
  End_Time timestamp,
  Start_Lat decimal(9,6),
  Start_Lng decimal(9,6),
  End_Lat decimal(9,6),
  End_Lng decimal(9,6),
  Distance decimal(10,2),
  Description varchar(255));''')
print("Table created successfully")

conn.commit()
conn.close()
# Out:
# Table created successfully

# %%
from sqlalchemy import create_engine
import MySQLdb
engine = create_engine("postgresql://postgres:root@localhost:5432/Accident")
con = engine.connect()
df_accident.to_sql(name = 'accident', con = con, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1788, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787     if not evt_handled:
# -> 1788         self.dialect.do_executemany(
#    1789             cursor, statement, parameters, context
#    1790         )
#    1791 elif not parameters and context.no_parameters:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py:951, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     950     xtras = self._psycopg2_extras()
# --> 951     context._psycopg2_fetched_rows = xtras.execute_values(
#     952         cursor,
#     953         statement,
#     954         parameters,
#     955         template=executemany_values,
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Create a sample DataFrame
# Connect to the PostgreSQL database
engine = create_engine("postgresql://postgres:root@localhost:5432/Accident")

# Load data into a new table in the database
df_accident.to_sql('accident', engine, if_exists='append', index=False)

# Close the database connection
engine.dispose()
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1788, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787     if not evt_handled:
# -> 1788         self.dialect.do_executemany(
#    1789             cursor, statement, parameters, context
#    1790         )
#    1791 elif not parameters and context.no_parameters:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py:951, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     950     xtras = self._psycopg2_extras()
# --> 951     context._psycopg2_fetched_rows = xtras.execute_values(
#     952         cursor,
#     953         statement,
#     954         parameters,
#     955         template=executemany_values,
# ...

# %%
df_accident.to_excel('accidenttable.xlsx', sheet_name='Sheet1', index=False)
